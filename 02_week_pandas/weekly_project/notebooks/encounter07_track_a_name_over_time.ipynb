# %% [markdown]
# # WEEK 02
# # Encounter 07 - Matplotlib
# # Project Challenge (PART 4) - Track a name over time

# %% [markdown]
# ## Task Description
#
#    1. Using any of the single name over time dataframes created in Filtering DataFrames
#    2. Create a line plot with the years and the (relative) frequencies of a specific name

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
name = 'Lebron'

df_name = pd.read_csv(f'../data/{name}_all_years.csv')
df_name
# Out:
#       name gender  frequency  year
# 0   Lebron      M          6  1925
# 1   Lebron      M          5  1926
# 2   Lebron      M          6  1933
# 3   Lebron      M          7  1938
# 4   Lebron      M         12  1939
# ..     ...    ...        ...   ...
# 64  Lebron      M         29  2016
# 65  Lebron      M         24  2017
# 66  Lebron      M         32  2018
# 67  Lebron      M         21  2019
# 68  Lebron      M         15  2020
#
# [69 rows x 4 columns]

# %%
# checking if there are a few recs for any particular year (year dups)
df_name.nunique()
# Out:
# name          1
# gender        1
# frequency    26
# year         69
# dtype: int64

# %% [markdown]
# As far as there are no years with (male, female) pair of names, no additional DataFrame filtering is required.

# %%
# Create a line plot with the years and the (relative) frequencies of a specific name

x_vals = df_name['year']
y_vals = df_name['frequency']

# plotting starts
plt.style.use('ggplot')
plt.figure(figsize=(10, 5))

plt.plot(x_vals, y_vals, label='name frequency per year', color='darkorange', linewidth=5)

# title
plt.title('The (relative) frequencies of "Lebron" name per year from 1880 to 2020')

# label names
plt.xlabel('Years')
plt.ylabel('Name Frequency')

# save plot at given path
#plt.savefig('../images/some_random_plot.pdf')
# Out:
# Text(0, 0.5, 'Name Frequency')

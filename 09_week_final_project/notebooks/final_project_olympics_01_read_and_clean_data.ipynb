# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### User-defined functions

# %%
# formatting column names
# the function gets dataframe as input and formats its column names; None is ruturned 
def format_columns(df):
    columns_lst = df.columns
    columns_lst = [x.lower() for x in columns_lst] # convert column names to lower case
    columns_lst = [x.replace(' (', '_') for x in columns_lst] # replace ' (' to underscore
    columns_lst = [x.replace(')', '') for x in columns_lst] # drop ')'
    df.columns = columns_lst

# %% [markdown]
# # Part 1 - Read data files

# %% [markdown]
# ### Summer Olympics data

# %%
# read csv-file
summer = pd.read_csv('../olympics/Athletes_summer_games.csv')
summer.drop(columns='Unnamed: 0', inplace=True)
summer
# Out:
#                                       Name Sex   Age            Team  NOC  \
# 0                                A Dijiang   M  24.0           China  CHN
# 1                                 A Lamusi   M  23.0           China  CHN
# 2                      Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3                     Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4       Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands  NED
# ...                                    ...  ..   ...             ...  ...
# 237668                   ZWOLINSKA Klaudia   F  22.0          Poland  POL
# 237669                        ZYKOVA Yulia   F  25.0          Russia  ROC
# 237670                   ZYUZINA Ekaterina   F  24.0          Russia  ROC
# 237671                     ZYZANSKA Sylwia   F  24.0          Poland  POL
# 237672                     ZYZANSKA Sylwia   F  24.0          Poland  POL
#
#               Games  Year  Season         City         Sport  \
# 0       1992 Summer  1992  Summer    Barcelona    Basketball
# 1       2012 Summer  2012  Summer       London          Judo
# 2       1920 Summer  1920  Summer    Antwerpen      Football
# 3       1900 Summer  1900  Summer        Paris    Tug-Of-War
# 4       1932 Summer  1932  Summer  Los Angeles     Athletics
# ...             ...   ...     ...          ...           ...
# 237668  2020 Summer  2020  Summer        Tokyo  Canoe Slalom
# 237669  2020 Summer  2020  Summer        Tokyo      Shooting
# 237670  2020 Summer  2020  Summer        Tokyo       Sailing
# 237671  2020 Summer  2020  Summer        Tokyo       Archery
# 237672  2020 Summer  2020  Summer        Tokyo       Archery
#
#                                            Event   Medal
# 0                    Basketball Men's Basketball     NaN
# 1                   Judo Men's Extra-Lightweight     NaN
# 2                        Football Men's Football     NaN
# 3                    Tug-Of-War Men's Tug-Of-War    Gold
# 4                   Athletics Women's 100 metres     NaN
# ...                                          ...     ...
# 237668                             Women's Kayak     NaN
# 237669               50m Rifle 3 Positions Women  Silver
# 237670  Women's One Person Dinghy - Laser Radial     NaN
# 237671                        Women's Individual     NaN
# 237672                                Mixed Team     NaN
#
# [237673 rows x 12 columns]

# %%
# update column names to lower case
format_columns(summer)
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237673 entries, 0 to 237672
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   name    237673 non-null  object
#  1   sex     237673 non-null  object
#  2   age     228484 non-null  float64
#  3   team    237673 non-null  object
#  4   noc     237673 non-null  object
#  5   games   237673 non-null  object
#  6   year    237673 non-null  int64
#  7   season  237673 non-null  object
#  8   city    237673 non-null  object
#  9   sport   237673 non-null  object
#  10  event   237673 non-null  object
#  11  medal   36537 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 21.8+ MB

# %%
# getting the 'complete row' duplicates: 1386 rows
summer_dups = summer[summer.duplicated()]
summer_dups
# Out:
#                                        name sex   age           team  noc  \
# 1066                     Dsir Antoine Acket   M  27.0        Belgium  BEL
# 3772                 William Truman Aldrich   M  48.0  United States  USA
# 3773                 William Truman Aldrich   M  48.0  United States  USA
# 4307                 Hermann Reinhard Alker   M  43.0        Germany  GER
# 4309                 Hermann Reinhard Alker   M  43.0        Germany  GER
# ...                                     ...  ..   ...            ...  ...
# 221722  Anna Katrina Zinkeisen (-Heseltine)   F  46.0  Great Britain  GBR
# 221723  Anna Katrina Zinkeisen (-Heseltine)   F  46.0  Great Britain  GBR
# 221725  Anna Katrina Zinkeisen (-Heseltine)   F  46.0  Great Britain  GBR
# 221727   Doris Clare Zinkeisen (-Johnstone)   F  49.0  Great Britain  GBR
# 221879                     Henri Achille Zo   M  58.0         France  FRA
#
#               games  year  season         city             sport  \
# 1066    1932 Summer  1932  Summer  Los Angeles  Art Competitions
# 3772    1928 Summer  1928  Summer    Amsterdam  Art Competitions
# 3773    1928 Summer  1928  Summer    Amsterdam  Art Competitions
# 4307    1928 Summer  1928  Summer    Amsterdam  Art Competitions
# 4309    1928 Summer  1928  Summer    Amsterdam  Art Competitions
# ...             ...   ...     ...          ...               ...
# 221722  1948 Summer  1948  Summer       London  Art Competitions
# 221723  1948 Summer  1948  Summer       London  Art Competitions
# 221725  1948 Summer  1948  Summer       London  Art Competitions
# 221727  1948 Summer  1948  Summer       London  Art Competitions
# 221879  1932 Summer  1932  Summer  Los Angeles  Art Competitions
#
#                                                     event medal
# 1066       Art Competitions Mixed Painting, Unknown Event   NaN
# 3772    Art Competitions Mixed Painting, Drawings And ...   NaN
# 3773    Art Competitions Mixed Painting, Drawings And ...   NaN
# 4307    Art Competitions Mixed Architecture, Designs F...   NaN
# 4309    Art Competitions Mixed Architecture, Architect...   NaN
# ...                                                   ...   ...
# 221722         Art Competitions Mixed Painting, Paintings   NaN
# 221723         Art Competitions Mixed Painting, Paintings   NaN
# 221725     Art Competitions Mixed Painting, Unknown Event   NaN
# 221727     Art Competitions Mixed Painting, Unknown Event   NaN
# 221879     Art Competitions Mixed Painting, Unknown Event   NaN
#
# [1386 rows x 12 columns]

# %%
# number of duplicated summer rows to drop:
237_673 - 236_287, (237_673 - 236_287)*100 / 237_673
# Out:
# (1386, 0.5831541655972702)

# %%
# dropping dups from SUMMER data
summer.drop_duplicates(inplace=True)
summer.info() # 237_673 -> 236_287 = 1_386 (0.58 % of initial summer dataset)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236287 entries, 0 to 237672
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   name    236287 non-null  object
#  1   sex     236287 non-null  object
#  2   age     227257 non-null  float64
#  3   team    236287 non-null  object
#  4   noc     236287 non-null  object
#  5   games   236287 non-null  object
#  6   year    236287 non-null  int64
#  7   season  236287 non-null  object
#  8   city    236287 non-null  object
#  9   sport   236287 non-null  object
#  10  event   236287 non-null  object
#  11  medal   36525 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 23.4+ MB

# %%
# adding birth_year
# summer['birth_year'] = summer['year'] - summer['age']. astype('Int64')

# %%
# checking for nulls in SUMMER data # 9_030 records
summer.isnull().sum()
# Out:
# name           0
# sex            0
# age         9030
# team           0
# noc            0
# games          0
# year           0
# season         0
# city           0
# sport          0
# event          0
# medal     199762
# dtype: int64

# %%
# no Age SUMMER rows
summer_no_age = summer[summer['age'].isnull()].sort_values(by='year', ascending=False)
summer_no_age
# Out:
#                               name sex  age         team  noc        games  \
# 31746                 Cha Yong-Hwa   F  NaN  North Korea  PRK  2008 Summer
# 31747                 Cha Yong-Hwa   F  NaN  North Korea  PRK  2008 Summer
# 133920                     Moosaka   F  NaN       Uganda  UGA  2000 Summer
# 149323        Raymond Anthony Papa   M  NaN  Philippines  PHI  1996 Summer
# 122153                 Abdou Manzo   M  NaN        Niger  NIG  1996 Summer
# ...                            ...  ..  ...          ...  ...          ...
# 168531               Richard Rstel   M  NaN      Germany  GER  1896 Summer
# 168530               Richard Rstel   M  NaN      Germany  GER  1896 Summer
# 40865           Evangelos Damaskos   M  NaN       Greece  GRE  1896 Summer
# 109508  Ioannis Georgios Lavrentis   M  NaN       Greece  GRE  1896 Summer
# 92511          Gyula Kakas (Kokas)   M  NaN      Hungary  HUN  1896 Summer
#
#         year  season     city         sport  \
# 31746   2008  Summer  Beijing    Gymnastics
# 31747   2008  Summer  Beijing    Gymnastics
# 133920  2000  Summer   Sydney  Table Tennis
# 149323  1996  Summer  Atlanta      Swimming
# 122153  1996  Summer  Atlanta     Athletics
# ...      ...     ...      ...           ...
# 168531  1896  Summer   Athina    Gymnastics
# 168530  1896  Summer   Athina    Gymnastics
# 40865   1896  Summer   Athina     Athletics
# 109508  1896  Summer   Athina     Athletics
# 92511   1896  Summer   Athina    Gymnastics
#
#                                            event   medal
# 31746   Gymnastics Women's Individual All-Around     NaN
# 31747             Gymnastics Women's Uneven Bars     NaN
# 133920              Table Tennis Women's Singles     NaN
# 149323      Swimming Men's 200 metres Backstroke     NaN
# 122153                  Athletics Men's Marathon     NaN
# ...                                          ...     ...
# 168531            Gymnastics Men's Parallel Bars     NaN
# 168530              Gymnastics Men's Horse Vault     NaN
# 40865                 Athletics Men's Pole Vault  Bronze
# 109508                  Athletics Men's Marathon     NaN
# 92511           Gymnastics Men's Pommelled Horse     NaN
#
# [9030 rows x 12 columns]

# %%
# O P T I O N A L:
# try to complete data with NaN 'age' values with the data from  different years...
# T O   D E B U G (in progress...)

# join to initial dataframe to get birth_year
# summer_no_age_upd = summer_no_age.merge(summer_no_age_source, how='inner', on=['name', 'noc'], suffixes=('_x', '_y'), copy=True)
# summer_no_age_upd

# %%
# checking if null 'age' values could be fixed
# summer_no_age['name'].nunique() # 
names_list_summer = summer_no_age['name'].unique()

summer[~(summer['age'].isnull()) & (summer['name'].isin(names_list_summer))] # 90 rows
# Out:
#                    name sex   age            team  noc        games  year  \
# 4123       Abdullah Ali   M  28.0           Egypt  EGY  1964 Summer  1964
# 4124       Abdullah Ali   M  28.0           Egypt  EGY  1964 Summer  1964
# 13340   Muhammad Bashir   M  25.0        Pakistan  PAK  1960 Summer  1960
# 13341   Muhammad Bashir   M  29.0        Pakistan  PAK  1964 Summer  1964
# 13343   Muhammad Bashir   M  17.0        Pakistan  PAK  1952 Summer  1952
# ...                 ...  ..   ...             ...  ...          ...   ...
# 198052        Josef Tom   M  30.0  Czechoslovakia  TCH  1964 Summer  1964
# 205258          Ji Vank   M  22.0  Czech Republic  CZE  2000 Summer  2000
# 205259          Ji Vank   M  30.0  Czech Republic  CZE  2008 Summer  2008
# 210310      Hugo Walser   M  24.0   Liechtenstein  LIE  1964 Summer  1964
# 210311      Hugo Walser   M  24.0   Liechtenstein  LIE  1964 Summer  1964
#
#         season      city      sport                                    event  \
# 4123    Summer     Tokyo     Rowing                 Rowing Men's Coxed Pairs
# 4124    Summer     Tokyo     Rowing                 Rowing Men's Coxed Fours
# 13340   Summer      Roma  Wrestling  Wrestling Men's Welterweight, Freestyle
# 13341   Summer     Tokyo  Wrestling   Wrestling Men's Lightweight, Freestyle
# 13343   Summer  Helsinki   Swimming   Swimming Men's 200 metres Breaststroke
# ...        ...       ...        ...                                      ...
# 198052  Summer     Tokyo  Athletics            Athletics Men's 10,000 metres
# 205258  Summer    Sydney     Tennis                     Tennis Men's Singles
# 205259  Summer   Beijing     Tennis                     Tennis Men's Singles
# 210310  Summer     Tokyo  Athletics               Athletics Men's 800 metres
# 210311  Summer     Tokyo  Athletics             Athletics Men's 1,500 metres
#
#          medal
# 4123       NaN
# 4124       NaN
# 13340   Bronze
# 13341      NaN
# 13343      NaN
# ...        ...
# 198052     NaN
# 205258     NaN
# 205259     NaN
# 210310     NaN
# 210311     NaN
#
# [90 rows x 12 columns]

# %%
# number of unique names for which we have missed age and other records with filled age
summer[~(summer['age'].isnull()) & (summer['name'].isin(names_list_summer))]['name'].nunique()
# Out:
# 45

# %%
# filtering our names which could be potentially fixed using another records with filled age
names_list_summer_source = summer[~(summer['age'].isnull()) & (summer['name'].isin(names_list_summer))]['name'].unique()
names_list_summer_source
# Out:
# array(['Abdullah Ali', 'Muhammad Bashir', 'Franois Bonnet',
#        'Jaroslav Bro', 'Fernando Cavallini', 'Eugne Coulon',
#        'Dimitrios Deligiannis', 'Mamadou Diallo', 'Mohamed El-Sayed',
#        'Ernst Gerlach', 'Francisco Gonzlez Suaste', 'Luis Gonzlez',
#        'Luis Hernndez', 'William Hill', 'Karl Hoffmann', 'Ernst Huber',
#        'Mohamed Ibrahim', 'Luis Jimnez Pea', 'Nikolay Karasyov',
#        'Ioannis Karyofyllis', 'Kim Yeong-Su', 'Kim Yong-Bae',
#        'Kazuo Kobayashi', 'Anatoly Ivanovich Kolesov',
#        'Konstantinos Konstantinou', 'Jzsef Kovcs', 'Lee Sang-Hun',
#        'James McKenzie', 'Pedro Mercado', 'Hans Mller', 'Bla Nagy',
#        'Alexandros Nikolopoulos', 'Henry Perry', 'Frantiek ez',
#        'Francisco Rodrguez', 'Sonja Roman', 'Hans Roth', 'Josef Schejbal',
#        'Johann Schulz', 'Erich Siebert', 'Baldev Singh', 'Devi Singh',
#        'Josef Tom', 'Ji Vank', 'Hugo Walser'], dtype=object)

# %%
# checking 1 particular name: if it is possible to fill missed 'age' 
summer[summer['name'] == 'Abdullah Ali']

# IMPORTANT: there could be the same 'name' with different 'noc'/'team';
#            also take care of dates ('age' to 'year' to 'year_with_missed_age')
# Out:
#               name sex   age     team  noc        games  year  season  \
# 4123  Abdullah Ali   M  28.0    Egypt  EGY  1964 Summer  1964  Summer
# 4124  Abdullah Ali   M  28.0    Egypt  EGY  1964 Summer  1964  Summer
# 4125  Abdullah Ali   M   NaN  Bahrain  BRN  1984 Summer  1984  Summer
#
#              city     sport  \
# 4123        Tokyo    Rowing
# 4124        Tokyo    Rowing
# 4125  Los Angeles  Shooting
#
#                                                   event medal
# 4123                           Rowing Men's Coxed Pairs   NaN
# 4124                           Rowing Men's Coxed Fours   NaN
# 4125  Shooting Men's Small-Bore Rifle, Prone, 50 metres   NaN

# %% [markdown]
# **How important missed 'age' data?**

# %%
# how many medals among the sportsmen with no Age:
summer_no_age['medal'].value_counts()
# Out:
# Silver    292
# Bronze    287
# Gold      138
# Name: medal, dtype: int64

# %%
# number of unique years for SUMMER sportsmen with no Age
summer_no_age['year'].nunique(), summer_no_age['year'].unique()
# Out:
# (26,
#  array([2008, 2000, 1996, 1992, 1988, 1984, 1980, 1976, 1972, 1968, 1964,
#         1960, 1956, 1952, 1948, 1936, 1932, 1928, 1924, 1920, 1912, 1908,
#         1906, 1904, 1900, 1896], dtype=int64))

# %% [markdown]
# **Resolution:**
#     Missed data could be essential for counting medals per age for particular sportsmen.
#     However medals per country could be calculated correctly!

# %% [markdown]
# ### Winter Olympics data

# %%
winter = pd.read_csv('../olympics/Athletes_winter_games.csv')
winter.drop(columns='Unnamed: 0', inplace=True)
winter
# Out:
#                            Name Sex   Age         Team  NOC        Games  \
# 0      Christine Jacoba Aaftink   F  21.0  Netherlands  NED  1988 Winter
# 1      Christine Jacoba Aaftink   F  21.0  Netherlands  NED  1988 Winter
# 2      Christine Jacoba Aaftink   F  25.0  Netherlands  NED  1992 Winter
# 3      Christine Jacoba Aaftink   F  25.0  Netherlands  NED  1992 Winter
# 4      Christine Jacoba Aaftink   F  27.0  Netherlands  NED  1994 Winter
# ...                         ...  ..   ...          ...  ...          ...
# 48559                Andrzej ya   M  29.0     Poland-1  POL  1976 Winter
# 48560                  Piotr ya   M  27.0       Poland  POL  2014 Winter
# 48561                  Piotr ya   M  27.0       Poland  POL  2014 Winter
# 48562        Tomasz Ireneusz ya   M  30.0       Poland  POL  1998 Winter
# 48563        Tomasz Ireneusz ya   M  34.0       Poland  POL  2002 Winter
#
#        Year  Season            City          Sport  \
# 0      1988  Winter         Calgary  Speed Skating
# 1      1988  Winter         Calgary  Speed Skating
# 2      1992  Winter     Albertville  Speed Skating
# 3      1992  Winter     Albertville  Speed Skating
# 4      1994  Winter     Lillehammer  Speed Skating
# ...     ...     ...             ...            ...
# 48559  1976  Winter       Innsbruck           Luge
# 48560  2014  Winter           Sochi    Ski Jumping
# 48561  2014  Winter           Sochi    Ski Jumping
# 48562  1998  Winter          Nagano      Bobsleigh
# 48563  2002  Winter  Salt Lake City      Bobsleigh
#
#                                           Event Medal
# 0              Speed Skating Women's 500 metres   NaN
# 1            Speed Skating Women's 1,000 metres   NaN
# 2              Speed Skating Women's 500 metres   NaN
# 3            Speed Skating Women's 1,000 metres   NaN
# 4              Speed Skating Women's 500 metres   NaN
# ...                                         ...   ...
# 48559                Luge Mixed (Men)'s Doubles   NaN
# 48560  Ski Jumping Men's Large Hill, Individual   NaN
# 48561        Ski Jumping Men's Large Hill, Team   NaN
# 48562                      Bobsleigh Men's Four   NaN
# 48563                      Bobsleigh Men's Four   NaN
#
# [48564 rows x 12 columns]

# %%
# update column names to lower case
format_columns(winter)

# %%
# getting the 'complete row' duplicates - NO DUPS!
winter_dups = winter[winter.duplicated()]
winter_dups
# Out:
# Empty DataFrame
# Columns: [name, sex, age, team, noc, games, year, season, city, sport, event, medal]
# Index: []

# %%
# checking data types  - ALL CORRECT!
winter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48564 entries, 0 to 48563
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    48564 non-null  object
#  1   sex     48564 non-null  object
#  2   age     48279 non-null  float64
#  3   team    48564 non-null  object
#  4   noc     48564 non-null  object
#  5   games   48564 non-null  object
#  6   year    48564 non-null  int64
#  7   season  48564 non-null  object
#  8   city    48564 non-null  object
#  9   sport   48564 non-null  object
#  10  event   48564 non-null  object
#  11  medal   5695 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 4.4+ MB

# %%
# adding birth_year
# winter['birth_year'] = winter['year'] - winter['age']. astype('Int64')

# %%
# checking for nulls
winter.isnull().sum()
# Out:
# name          0
# sex           0
# age         285
# team          0
# noc           0
# games         0
# year          0
# season        0
# city          0
# sport         0
# event         0
# medal     42869
# dtype: int64

# %%
# checking if null 'Age' values could be fixed
winter_no_age = winter[winter['age'].isnull()].sort_values(by='year', ascending=False) #, ignore_index=False)
winter_no_age
# Out:
#                                 name sex  age           team  noc  \
# 25608  Christopher Paul "Chris" Lori   M  NaN       Canada-2  CAN
# 25609  Christopher Paul "Chris" Lori   M  NaN       Canada-2  CAN
# 25606  Christopher Paul "Chris" Lori   M  NaN       Canada-2  CAN
# 25607  Christopher Paul "Chris" Lori   M  NaN       Canada-2  CAN
# 25605  Christopher Paul "Chris" Lori   M  NaN       Canada-1  CAN
# ...                              ...  ..  ...            ...  ...
# 16176        Antoine "Antonio" Herin   M  NaN          Italy  ITA
# 16164               Georgette Herbos   F  NaN        Belgium  BEL
# 16163                  Paolo Herbert   M  NaN        Italy-1  ITA
# 14513                 Anton Guldener   M  NaN  Switzerland-2  SUI
# 38875                  Pembra Sherpa   M  NaN          India  IND
#
#              games  year  season         city                 sport  \
# 25608  1998 Winter  1998  Winter       Nagano             Bobsleigh
# 25609  1998 Winter  1998  Winter       Nagano             Bobsleigh
# 25606  1994 Winter  1994  Winter  Lillehammer             Bobsleigh
# 25607  1994 Winter  1994  Winter  Lillehammer             Bobsleigh
# 25605  1992 Winter  1992  Winter  Albertville             Bobsleigh
# ...            ...   ...     ...          ...                   ...
# 16176  1924 Winter  1924  Winter     Chamonix  Cross Country Skiing
# 16164  1924 Winter  1924  Winter     Chamonix        Figure Skating
# 16163  1924 Winter  1924  Winter     Chamonix             Bobsleigh
# 14513  1924 Winter  1924  Winter     Chamonix             Bobsleigh
# 38875  1924 Winter  1924  Winter     Chamonix              Alpinism
#
#                                           event medal
# 25608                       Bobsleigh Men's Two   NaN
# 25609                      Bobsleigh Men's Four   NaN
# 25606                       Bobsleigh Men's Two   NaN
# 25607                      Bobsleigh Men's Four   NaN
# 25605                      Bobsleigh Men's Four   NaN
# ...                                         ...   ...
# 16176  Cross Country Skiing Men's 18 kilometres   NaN
# 16164                Figure Skating Mixed Pairs   NaN
# 16163                 Bobsleigh Men's Four/Five   NaN
# 14513                 Bobsleigh Men's Four/Five   NaN
# 38875                   Alpinism Mixed Alpinism  Gold
#
# [285 rows x 12 columns]

# %%
# unique 'names' with missed 'age' data
#winter_no_age['name'].nunique() # 194
names_list = winter_no_age['name'].unique()

winter[~(winter['age'].isnull()) & (winter['name'].isin(names_list))]  # only 1 name = 'Giuseppe Steiner' (born in 1930)
# Out:
#                    name sex   age   team  noc        games  year  season  \
# 40867  Giuseppe Steiner   M  30.0  Italy  ITA  1960 Winter  1960  Winter
# 40868  Giuseppe Steiner   M  30.0  Italy  ITA  1960 Winter  1960  Winter
# 40869  Giuseppe Steiner   M  30.0  Italy  ITA  1960 Winter  1960  Winter
# 40870  Giuseppe Steiner   M  34.0  Italy  ITA  1964 Winter  1964  Winter
# 40871  Giuseppe Steiner   M  34.0  Italy  ITA  1964 Winter  1964  Winter
# 40872  Giuseppe Steiner   M  34.0  Italy  ITA  1964 Winter  1964  Winter
#
#                city                 sport  \
# 40867  Squaw Valley  Cross Country Skiing
# 40868  Squaw Valley  Cross Country Skiing
# 40869  Squaw Valley  Cross Country Skiing
# 40870     Innsbruck  Cross Country Skiing
# 40871     Innsbruck  Cross Country Skiing
# 40872     Innsbruck  Cross Country Skiing
#
#                                                    event medal
# 40867           Cross Country Skiing Men's 15 kilometres   NaN
# 40868           Cross Country Skiing Men's 30 kilometres   NaN
# 40869  Cross Country Skiing Men's 4 x 10 kilometres R...   NaN
# 40870           Cross Country Skiing Men's 15 kilometres   NaN
# 40871           Cross Country Skiing Men's 30 kilometres   NaN
# 40872  Cross Country Skiing Men's 4 x 10 kilometres R...   NaN

# %%
# NO missed Age could be fixed because there is only 1 sportsmen with different participation year and he is too old
# it's a different Giuseppe Steiner!
winter_no_age[winter_no_age['name']=='Giuseppe Steiner']
# Out:
#                    name sex  age     team  noc        games  year  season  \
# 40873  Giuseppe Steiner   M  NaN  Italy-1  ITA  1924 Winter  1924  Winter
#
#            city      sport                      event medal
# 40873  Chamonix  Bobsleigh  Bobsleigh Men's Four/Five   NaN

# %% [markdown]
# ### Regions data (a part of Olympics data set)

# %%
regions = pd.read_csv('../olympics/regions.csv')
regions
# Out:
#      Unnamed: 0  NOC       region        notes
# 0             0  EOR      Refugee          NaN
# 1             1  LBN      Lebanon          NaN
# 2             2  SGP    Singapore          NaN
# 3             3  ROC       Russia          NaN
# 4             4  AFG  Afghanistan          NaN
# ..          ...  ...          ...          ...
# 229         229  YEM        Yemen          NaN
# 230         230  YMD        Yemen  South Yemen
# 231         231  YUG       Serbia   Yugoslavia
# 232         232  ZAM       Zambia          NaN
# 233         233  ZIM     Zimbabwe          NaN
#
# [234 rows x 4 columns]

# %%
# regions.columns
#Index(['Unnamed: 0', 'NOC', 'region', 'notes'], dtype='object')

regions.drop(columns='Unnamed: 0', inplace=True)

# update column names to lower case
format_columns(regions)

regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   noc     234 non-null    object
#  1   region  231 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.6+ KB

# %%
# getting the 'complete row' duplicates      - NO DUPS!
regions_dups = regions[regions.duplicated()]
regions_dups
# Out:
# Empty DataFrame
# Columns: [noc, region, notes]
# Index: []

# %% [markdown]
# ### Getting the single dataset (winter and summer)

# %%
# joining summer and winter data
olympics = pd.concat([summer, winter], axis=0, ignore_index=True) #concatenating df1 and df2 along rows; reset_index
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284851 entries, 0 to 284850
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   name    284851 non-null  object
#  1   sex     284851 non-null  object
#  2   age     275536 non-null  float64
#  3   team    284851 non-null  object
#  4   noc     284851 non-null  object
#  5   games   284851 non-null  object
#  6   year    284851 non-null  int64
#  7   season  284851 non-null  object
#  8   city    284851 non-null  object
#  9   sport   284851 non-null  object
#  10  event   284851 non-null  object
#  11  medal   42220 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 26.1+ MB

# %%
olympics
# Out:
#                                       name sex   age            team  noc  \
# 0                                A Dijiang   M  24.0           China  CHN
# 1                                 A Lamusi   M  23.0           China  CHN
# 2                      Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3                     Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4       Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands  NED
# ...                                    ...  ..   ...             ...  ...
# 284846                          Andrzej ya   M  29.0        Poland-1  POL
# 284847                            Piotr ya   M  27.0          Poland  POL
# 284848                            Piotr ya   M  27.0          Poland  POL
# 284849                  Tomasz Ireneusz ya   M  30.0          Poland  POL
# 284850                  Tomasz Ireneusz ya   M  34.0          Poland  POL
#
#               games  year  season            city        sport  \
# 0       1992 Summer  1992  Summer       Barcelona   Basketball
# 1       2012 Summer  2012  Summer          London         Judo
# 2       1920 Summer  1920  Summer       Antwerpen     Football
# 3       1900 Summer  1900  Summer           Paris   Tug-Of-War
# 4       1932 Summer  1932  Summer     Los Angeles    Athletics
# ...             ...   ...     ...             ...          ...
# 284846  1976 Winter  1976  Winter       Innsbruck         Luge
# 284847  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 284848  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 284849  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 284850  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            event medal
# 0                    Basketball Men's Basketball   NaN
# 1                   Judo Men's Extra-Lightweight   NaN
# 2                        Football Men's Football   NaN
# 3                    Tug-Of-War Men's Tug-Of-War  Gold
# 4                   Athletics Women's 100 metres   NaN
# ...                                          ...   ...
# 284846                Luge Mixed (Men)'s Doubles   NaN
# 284847  Ski Jumping Men's Large Hill, Individual   NaN
# 284848        Ski Jumping Men's Large Hill, Team   NaN
# 284849                      Bobsleigh Men's Four   NaN
# 284850                      Bobsleigh Men's Four   NaN
#
# [284851 rows x 12 columns]

# %%
winter.shape, summer.shape, olympics.shape
# Out:
# ((48564, 12), (236287, 12), (284851, 12))

# %% [markdown]
# ### Adding 'region' (Country Name) to olympics data from regions

# %%
# join to initial dataframe to get birth_year
olympics = olympics.merge(regions[['noc', 'region']], how='left', on=['noc'], copy=True)
olympics.rename(columns={"region": "country"}, inplace=True)
olympics
# Out:
#                                       name sex   age            team  noc  \
# 0                                A Dijiang   M  24.0           China  CHN
# 1                                 A Lamusi   M  23.0           China  CHN
# 2                      Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3                     Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4       Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands  NED
# ...                                    ...  ..   ...             ...  ...
# 284846                          Andrzej ya   M  29.0        Poland-1  POL
# 284847                            Piotr ya   M  27.0          Poland  POL
# 284848                            Piotr ya   M  27.0          Poland  POL
# 284849                  Tomasz Ireneusz ya   M  30.0          Poland  POL
# 284850                  Tomasz Ireneusz ya   M  34.0          Poland  POL
#
#               games  year  season            city        sport  \
# 0       1992 Summer  1992  Summer       Barcelona   Basketball
# 1       2012 Summer  2012  Summer          London         Judo
# 2       1920 Summer  1920  Summer       Antwerpen     Football
# 3       1900 Summer  1900  Summer           Paris   Tug-Of-War
# 4       1932 Summer  1932  Summer     Los Angeles    Athletics
# ...             ...   ...     ...             ...          ...
# 284846  1976 Winter  1976  Winter       Innsbruck         Luge
# 284847  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 284848  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 284849  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 284850  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            event medal      country
# 0                    Basketball Men's Basketball   NaN        China
# 1                   Judo Men's Extra-Lightweight   NaN        China
# 2                        Football Men's Football   NaN      Denmark
# 3                    Tug-Of-War Men's Tug-Of-War  Gold      Denmark
# 4                   Athletics Women's 100 metres   NaN  Netherlands
# ...                                          ...   ...          ...
# 284846                Luge Mixed (Men)'s Doubles   NaN       Poland
# 284847  Ski Jumping Men's Large Hill, Individual   NaN       Poland
# 284848        Ski Jumping Men's Large Hill, Team   NaN       Poland
# 284849                      Bobsleigh Men's Four   NaN       Poland
# 284850                      Bobsleigh Men's Four   NaN       Poland
#
# [284851 rows x 13 columns]

# %%
# save olympics data as csv
olympics.to_csv(path_or_buf='../olympics/olympics_upd.csv', index=False,
                sep=',', na_rep='', header=True, mode='w', encoding='utf-8', decimal='.')

# %% [markdown]
# ### Countries data (external source)

# %%
# https://cloford.com/resources/codes/index.htm

# %%
countries_main = pd.read_csv('../olympics/countries.csv')
countries_main
# Out:
#     Continent             Region                   Country           Capital  \
# 0        Asia         South Asia               Afghanistan             Kabul
# 1      Europe  South East Europe                   Albania            Tirana
# 2      Africa    Northern Africa                   Algeria           Algiers
# 3     Oceania            Pacific            American Samoa         Pago Pago
# 4      Europe  South West Europe                   Andorra  Andorra la Vella
# ..        ...                ...                       ...               ...
# 227   Oceania            Pacific             Western Samoa              Apia
# 228      Asia    South West Asia                     Yemen             Sanaa
# 229    Africa     Central Africa  Zaire (Dem Rep of Congo)          Kinshasa
# 230    Africa    Southern Africa                    Zambia            Lusaka
# 231    Africa    Southern Africa                  Zimbabwe            Harare
#
#     FIPS ISO (2) ISO (3)  ISO (No) Internet  Note
# 0     AF      AF     AFG       4.0       AF   NaN
# 1     AL      AL     ALB       8.0       AL   NaN
# 2     AG      DZ     DZA      12.0       DZ   NaN
# 3     AQ      AS     ASM      16.0       AS   NaN
# 4     AN      AD     AND      20.0       AD   NaN
# ..   ...     ...     ...       ...      ...   ...
# 227   WS      WS     WSM     882.0       WS   NaN
# 228   YM      YE     YEM     887.0       YE   NaN
# 229   CG      ZR     ZAR     180.0       ZR   8.0
# 230   ZA      ZM     ZWB     894.0       ZM   NaN
# 231   ZI      ZW     ZWE     716.0       ZW   NaN
#
# [232 rows x 10 columns]

# %%
# updating column names to lower case (and replacing parentheses with underscore)
format_columns(countries_main)

# %%
countries_add = pd.read_csv('../olympics/countries_additional.csv')
countries_add
# Out:
#          Continent                 Region  \
# 0             Asia              East Asia
# 1             Asia              East Asia
# 2       Antarctica             Antarctica
# 3   Atlantic Ocean   South Atlantic Ocean
# 4             Asia             South Asia
# 5             Asia        South East Asia
# 6           Europe         Western Europe
# 7     Indian Ocean  Southern Indian Ocean
# 8     Indian Ocean  Southern Indian Ocean
# 9           Europe      South East Europe
# 10  Atlantic Ocean   South Atlantic Ocean
# 11  Atlantic Ocean   South Atlantic Ocean
# 12         Oceania    North Pacific Ocean
# 13          Europe      South East Europe
#
#                                          Country   Capital FIPS ISO (2)  \
# 0                              Hong Kong (China)  Victoria   HK      HK
# 1                                  Macau (China)     Macau   MC      MO
# 2                                     Antarctica       NaN   AY      AQ
# 3                                  Bouvet Island       NaN   BV      BV
# 4                 British Indian Ocean Territory       NaN   IO      IO
# 5                                     East Timor       NaN   --      TP
# 6                           France, Metropolitan       NaN   --      FX
# 7            French Southern and Antarctic Lands       NaN   FS      TF
# 8              Heard Island and McDonald Islands       NaN   HM      HM
# 9                                     Montenegro       NaN   MW      --
# 10                                  Saint Helena       NaN   SH      SH
# 11  South Georgia and the South Sandwich Islands       NaN   SX      GS
# 12          United States Minor Outlying Islands       NaN   --      UM
# 13                                   Yugoslavia*       NaN   --      YU
#
#    ISO (3)  ISO (No) Internet  Note
# 0      HKG     344.0       HK   NaN
# 1      MAC     446.0       MO   NaN
# 2      ATA      10.0       AQ   9.0
# 3      BVT      74.0       BV   NaN
# 4      IOT      86.0       IO   NaN
# 5      TMP     626.0       TP  10.0
# 6      FXX     249.0       FX  11.0
# 7      ATF     260.0       --  12.0
# 8      HMD     334.0       HM   NaN
# 9       --       NaN       --   5.0
# 10     SHN     654.0       SH   NaN
# 11     SGS     239.0       GS   NaN
# 12     UMI     581.0       UM  13.0
# 13     YUG     891.0       YU   5.0

# %%
# updating column names to lower case (and replacing parentheses with underscore)
format_columns(countries_add)

# %%
# checking if contries sets are overlaping by iso3 codes
countries_add[countries_add['iso_3'].isin(countries_main['iso_3'])]
# Out:
#   continent             region     country capital fips iso_2 iso_3  iso_no  \
# 9    Europe  South East Europe  Montenegro     NaN   MW    --    --     NaN
#
#   internet  note
# 9       --   5.0

# %%
# checking if countries sets are overlaping by iso3 codes (backwards)
countries_main[countries_main['iso_3'].isin(countries_add['iso_3'])]
# Out:
#     continent             region                country               capital  \
# 84     Europe     Western Europe               Guernsey      Saint Peter Port
# 101    Europe    Northern Europe              Jan Mayen                     -
# 103    Europe     Western Europe                 Jersey          Saint Helier
# 128    Europe     Western Europe           Man, Isle of               Douglas
# 160      Asia    South West Asia              Palestine                   NaN
# 183    Europe  South East Europe  Serbia and Montenegro  Belgrade / Podgorica
#
#     fips iso_2 iso_3  iso_no internet  note
# 84    --    --    --     NaN       --   NaN
# 101   --    --    --     NaN       --   NaN
# 103   --    --    --     NaN       --   NaN
# 128   --    --    --     NaN       --   NaN
# 160   --    --    --     NaN       --   NaN
# 183   SR    --    --     NaN       --   5.0

# %%
# concatenating COUNTRIES data
countries = pd.concat([countries_main, countries_add], axis=0, ignore_index=True) #concatenating df1 and df2 along rows
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   continent  246 non-null    object
#  1   region     246 non-null    object
#  2   country    246 non-null    object
#  3   capital    233 non-null    object
#  4   fips       245 non-null    object
#  5   iso_2      245 non-null    object
#  6   iso_3      246 non-null    object
#  7   iso_no     239 non-null    float64
#  8   internet   245 non-null    object
#  9   note       15 non-null     float64
# dtypes: float64(2), object(8)
# memory usage: 19.3+ KB

# %%
# replacing '--' values with NaN values
for col in countries.columns:
    countries.loc[countries[col] == '--', col] = np.nan

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   continent  246 non-null    object
#  1   region     246 non-null    object
#  2   country    246 non-null    object
#  3   capital    233 non-null    object
#  4   fips       236 non-null    object
#  5   iso_2      238 non-null    object
#  6   iso_3      239 non-null    object
#  7   iso_no     239 non-null    float64
#  8   internet   237 non-null    object
#  9   note       15 non-null     float64
# dtypes: float64(2), object(8)
# memory usage: 19.3+ KB

# %%
# save countries cleaned data
countries.to_csv(path_or_buf='../olympics/countries_upd.csv', index=False,
                sep=',', na_rep='', header=True, mode='w', encoding='utf-8', decimal='.')

# %%
# tmp
# comparing list of iso-3 countries with 'noc' from 'olympics'
countries['country'].nunique() , countries['iso_3'].nunique(),  olympics['noc'].nunique()
# (246, 239, 233)
# Out:
# (246, 239, 233)

# %% [markdown]
# ### Getting 'country' name source field (for farther manipulation)

# %%
# Example of National Olympic Committee code which differs from iso3 country code:
olympics[olympics['noc']=='URS'] # Soviet Union
# Out:
#                                             name sex   age          team  noc  \
# 130                 Rost'om Omeris dze Abashidze   M  29.0  Soviet Union  URS
# 131     Nunu Dzhansuhivna Abashydze (-Myslaieva)   F  25.0  Soviet Union  URS
# 481             Zagalav Abdulbekovich Abdulbekov   M  26.0  Soviet Union  URS
# 553     Dzhamolidin Mirgarifanovich Abduzhaparov   M  24.0  Soviet Union  URS
# 706                   Viktor Andreyevich Aboimov   M  22.0  Soviet Union  URS
# ...                                          ...  ..   ...           ...  ...
# 284519              Nikolay Semyonovich Zimyatov   M  28.0  Soviet Union  URS
# 284522              Viktor Aleksandrovich Zinger   M  26.0  Soviet Union  URS
# 284659                   Vera Zozua (-Pyatnizin)   F  20.0  Soviet Union  URS
# 284660                   Vera Zozua (-Pyatnizin)   F  24.0  Soviet Union  URS
# 284661                   Vera Zozua (-Pyatnizin)   F  28.0  Soviet Union  URS
#
#               games  year  season         city                 sport  \
# 130     1964 Summer  1964  Summer        Tokyo             Wrestling
# 131     1980 Summer  1980  Summer       Moskva             Athletics
# 481     1972 Summer  1972  Summer       Munich             Wrestling
# 553     1988 Summer  1988  Summer        Seoul               Cycling
# 706     1972 Summer  1972  Summer       Munich              Swimming
# ...             ...   ...     ...          ...                   ...
# 284519  1984 Winter  1984  Winter     Sarajevo  Cross Country Skiing
# 284522  1968 Winter  1968  Winter     Grenoble            Ice Hockey
# 284659  1976 Winter  1976  Winter    Innsbruck                  Luge
# 284660  1980 Winter  1980  Winter  Lake Placid                  Luge
# 284661  1984 Winter  1984  Winter     Sarajevo                  Luge
#
#                                                     event   medal country
# 130        Wrestling Men's Light-Heavyweight, Greco-Roman     NaN  Russia
# 131                            Athletics Women's Shot Put     NaN  Russia
# 481              Wrestling Men's Featherweight, Freestyle    Gold  Russia
# 553                   Cycling Men's Road Race, Individual     NaN  Russia
# 706                   Swimming Men's 400 metres Freestyle     NaN  Russia
# ...                                                   ...     ...     ...
# 284519  Cross Country Skiing Men's 4 x 10 kilometres R...  Silver  Russia
# 284522                        Ice Hockey Men's Ice Hockey    Gold  Russia
# 284659                               Luge Women's Singles     NaN  Russia
# 284660                               Luge Women's Singles    Gold  Russia
# 284661                               Luge Women's Singles     NaN  Russia
#
# [5685 rows x 13 columns]

# %%
# getting 'regions' data for particular National Olympic Committee code (which differs from iso3 country code) 
regions[regions['noc']=='URS']
# Out:
#      noc  region notes
# 218  URS  Russia   NaN

# %%
# checking if 'region' could be used as 'country_name' - OK!
regions[regions['region']=='Russia']
# Out:
#      noc  region notes
# 3    ROC  Russia   NaN
# 70   EUN  Russia   NaN
# 175  RUS  Russia   NaN
# 218  URS  Russia   NaN

# %%
# checking if 'region' could vary for a particular country -> NO, all correct!
regions[regions['region'].str.contains('USA', case=False, na=False)] # analog for ' where col_val like "%USA%" '
# Out:
#      noc region notes
# 220  USA    USA   NaN

# %%
# checking the completeness of 'regions' data (supposed to be OK)
regions.isnull().sum()
# Out:
# noc         0
# region      3
# notes     213
# dtype: int64

# %%
# cheking example of 'team' values for particular National Olympic Committee
olympics[olympics['noc']=='ARG']['team'].unique()

# RESULTS: 'team' could not be used as 'country' name !!
# Out:
# array(['Argentina', 'Matrero II', 'Blue Red', 'Argentina-2', 'Pampero',
#        'Wiking', 'Cupidon III', 'Arcturus', 'Covunco III', 'Tango',
#        'Argentina-1', 'Acturus', 'Antares', 'Mizar', 'Gullvinge', 'Djinn',
#        'Rampage', 'Ardilla'], dtype=object)

# %%
# Checking if a contry name (regions.region) unique: NO!
regions.shape, regions['region'].nunique()
# Out:
# ((234, 3), 207)

# %% [markdown]
# ### Joining 'regions' and 'countries' data to get 'iso3' codes for country names (the way they used in Olympics data)

# %%
# joining 'regions' and 'countries'
iso3_for_country = pd.merge(left=regions, right=countries, how='left', left_on='region', right_on='country', suffixes=('_x', '_y'))
# 234 rows in iso3_for_country

missed_iso3 = iso3_for_country[iso3_for_country['country'].isnull()]
missed_iso3 =  missed_iso3[['noc', 'region_x', 'notes']] # 32 rows (with missed iso3)

iso3_for_country.shape, missed_iso3.shape, missed_iso3['region_x'].nunique()
# Out:
# ((234, 13), (32, 3), 26)

# %%
# list of successfully merged countries
mapped_iso3 = iso3_for_country[~(iso3_for_country['country'].isnull())]
#mapped_iso3
mapped_iso3.shape, mapped_iso3['region_x'].nunique()
# Out:
# ((202, 13), 181)

# %%
missed_iso3[missed_iso3['region_x'].isin(mapped_iso3['region_x'].unique())]
# Out:
# Empty DataFrame
# Columns: [noc, region_x, notes]
# Index: []

# %%
# missed iso3 mapping list
missed_iso3_countries = missed_iso3['region_x'].unique()
missed_iso3_countries
# Out:
# array(['Refugee', 'Curacao', 'Antigua', 'Bahamas', 'Boliva',
#        'Republic of Congo', 'Ivory Coast',
#        'Democratic Republic of the Congo', 'Micronesia', 'Gambia', 'UK',
#        'Individual Olympic Athletes', 'Virgin Islands, US',
#        'Virgin Islands, British', 'South Korea', 'Kosovo', 'Myanmar',
#        'North Korea', nan, 'Samoa', 'Serbia', 'Saint Kitts',
#        'South Sudan', 'Timor-Leste', 'Trinidad', 'USA', 'Saint Vincent'],
#       dtype=object)

# %%
missed_iso3.reset_index(drop=True, inplace=True)
missed_iso3
# Out:
#     noc                          region_x                        notes
# 0   EOR                           Refugee                          NaN
# 1   AHO                           Curacao         Netherlands Antilles
# 2   ANT                           Antigua          Antigua and Barbuda
# 3   BAH                           Bahamas                          NaN
# 4   BOL                            Boliva                          NaN
# 5   CGO                 Republic of Congo                          NaN
# 6   CIV                       Ivory Coast                          NaN
# 7   COD  Democratic Republic of the Congo                          NaN
# 8   FSM                        Micronesia                          NaN
# 9   GAM                            Gambia                          NaN
# 10  GBR                                UK                          NaN
# 11  IOA       Individual Olympic Athletes  Individual Olympic Athletes
# 12  ISV                Virgin Islands, US               Virgin Islands
# 13  IVB           Virgin Islands, British                          NaN
# 14  KOR                       South Korea                          NaN
# 15  KOS                            Kosovo                          NaN
# 16  MYA                           Myanmar                          NaN
# 17  PRK                       North Korea                          NaN
# 18  ROT                               NaN         Refugee Olympic Team
# 19  SAM                             Samoa                          NaN
# 20  SCG                            Serbia        Serbia and Montenegro
# 21  SKN                       Saint Kitts     Turks and Caicos Islands
# 22  SRB                            Serbia                          NaN
# 23  SSD                       South Sudan                          NaN
# 24  TLS                       Timor-Leste                          NaN
# 25  TTO                          Trinidad          Trinidad and Tobago
# 26  TUV                               NaN                       Tuvalu
# 27  UNK                               NaN                      Unknown
# 28  USA                               USA                          NaN
# 29  VIN                     Saint Vincent                          NaN
# 30  WIF                          Trinidad       West Indies Federation
# 31  YUG                            Serbia                   Yugoslavia

# %%
# examples of missed mapping

# Python syntaxis:
# Series.str.contains(pat, case=True, flags=0, na=None, regex=True)

country = 'USA' # missed_iso3['region_x']
noc = regions[regions['region']==country]['noc'].iloc[0]
print(noc)
iso3_by_region = (countries[countries['country'].str.contains(country, regex = False)]['iso_3'].to_list()[:1] or [None])[0]
print(iso3_by_region) # None

iso3_by_noc = (countries[countries['iso_3']== noc]['iso_3'].to_list()[:1] or [None])[0]
print(iso3_by_noc)
# Out:
# USA
# None
# USA

# %%
# update missed_iso3 DataFrame:
# - add 'iso3_by_region' column
# - add 'iso3_by_noc' column
# - add 'iso3_by_notes' column
# - add 'iso3' as 'iso3_by_region' or 'iso3_by_notes' or 'iso3_by_noc' (TO CHECK: could be incorrect!)

missed_iso3['iso3_by_region'] = None
missed_iso3['iso3_by_notes'] = None
missed_iso3['iso3_by_noc'] = None
missed_iso3['iso3'] = None

# update mised 'region_x' values ('NaN') with 'notes'
missed_iso3['region_x'] = np.where(missed_iso3['region_x'].isna(), missed_iso3['notes'], missed_iso3['region_x'])

# tie to 'countries' data and get 'iso3' values using country name or 'noc'
for i in range(len(missed_iso3)):
    country = missed_iso3.at[i, 'region_x']
    noc = missed_iso3.at[i, 'noc']
    
    notes = missed_iso3.at[i, 'notes'] 
    if str(notes) == 'nan': # replace 'NaN' values with some text
        notes = 'Not defined value'+str(i)
    
    missed_iso3.at[i, 'iso3_by_region'] = (countries[countries['country'].str.contains(country, regex = False)]['iso_3'].to_list()[:1] or [None])[0]
    missed_iso3.at[i, 'iso3_by_notes'] = (countries[countries['country'].str.contains(notes, regex = False)]['iso_3'].to_list()[:1] or [None])[0]
    missed_iso3.at[i, 'iso3_by_noc'] = (countries[countries['iso_3']== noc]['iso_3'].to_list()[:1] or [None])[0]

# updating 'iso3' column in DataFrame using numpy: where(condition, value_if_True, value_if_False)
missed_iso3['iso3'] = np.where(missed_iso3['iso3_by_region'].isna(), missed_iso3['iso3_by_notes'], missed_iso3['iso3_by_region'])
missed_iso3['iso3'] = np.where(missed_iso3['iso3'].isna(), missed_iso3['iso3_by_noc'], missed_iso3['iso3'])

missed_iso3[['region_x', 'iso3']]
# Out:
#                             region_x  iso3
# 0                            Refugee  None
# 1                            Curacao   ANT
# 2                            Antigua   ATG
# 3                            Bahamas   BHS
# 4                             Boliva   BOL
# 5                  Republic of Congo  None
# 6                        Ivory Coast   CIV
# 7   Democratic Republic of the Congo  None
# 8                         Micronesia   FSM
# 9                             Gambia   GMB
# 10                                UK   GBR
# 11       Individual Olympic Athletes  None
# 12                Virgin Islands, US   VGB
# 13           Virgin Islands, British  None
# 14                       South Korea   KOR
# 15                            Kosovo  None
# 16                           Myanmar   MMR
# 17                       North Korea   PRK
# 18              Refugee Olympic Team  None
# 19                             Samoa   ASM
# 20                            Serbia  None
# 21                       Saint Kitts   KNA
# 22                            Serbia  None
# 23                       South Sudan  None
# 24                       Timor-Leste  None
# 25                          Trinidad   TTO
# 26                            Tuvalu   TUV
# 27                           Unknown  None
# 28                               USA   USA
# 29                     Saint Vincent   VCT
# 30                          Trinidad   TTO
# 31                            Serbia   YUG

# %%
# checking the computed results
missed_iso3[~(missed_iso3['iso3'].isnull())][['region_x', 'iso3']]

# All correct except for 'Serbia': 'YUG' should be updated to 'SRB' !!!
# Out:
#               region_x iso3
# 1              Curacao  ANT
# 2              Antigua  ATG
# 3              Bahamas  BHS
# 4               Boliva  BOL
# 6          Ivory Coast  CIV
# 8           Micronesia  FSM
# 9               Gambia  GMB
# 10                  UK  GBR
# 12  Virgin Islands, US  VGB
# 14         South Korea  KOR
# 16             Myanmar  MMR
# 17         North Korea  PRK
# 19               Samoa  ASM
# 21         Saint Kitts  KNA
# 25            Trinidad  TTO
# 26              Tuvalu  TUV
# 28                 USA  USA
# 29       Saint Vincent  VCT
# 30            Trinidad  TTO
# 31              Serbia  YUG

# %%
# country values without 'iso3'
# checking the computed results
missed_iso3[missed_iso3['iso3'].isnull()][['region_x', 'iso3']]
# Out:
#                             region_x  iso3
# 0                            Refugee  None
# 5                  Republic of Congo  None
# 7   Democratic Republic of the Congo  None
# 11       Individual Olympic Athletes  None
# 13           Virgin Islands, British  None
# 15                            Kosovo  None
# 18              Refugee Olympic Team  None
# 20                            Serbia  None
# 22                            Serbia  None
# 23                       South Sudan  None
# 24                       Timor-Leste  None
# 27                           Unknown  None

# %%
# iso3 to update (see previous list)

dict_iso3_to_update = {'iso3' : ['COG', 'COD', 'VGB', 'SRB', 'SSD', 'TLS'],
        'region_x' : ['Republic of Congo', 'Democratic Republic of the Congo', 
                      'Virgin Islands, British', 'Serbia', 'South Sudan', 'Timor-Leste']}

iso3_to_update = pd.DataFrame(dict_iso3_to_update)
iso3_to_update
# Out:
#   iso3                          region_x
# 0  COG                 Republic of Congo
# 1  COD  Democratic Republic of the Congo
# 2  VGB           Virgin Islands, British
# 3  SRB                            Serbia
# 4  SSD                       South Sudan
# 5  TLS                       Timor-Leste

# %% [markdown]
# **Final List for (country_name,iso3) pairs to use:**

# %%
# getting correctly mapped (country_name, iso3) pairs after joining countries data (external) with regions (olympics data)
mapped_iso3_pairs = mapped_iso3[['region_x', 'iso_3']]

# rename a 'iso_3' column
mapped_iso3_pairs.rename(columns={'iso_3': 'iso3'}, inplace=True)

mapped_iso3_pairs['iso3'].nunique() # 202 records, 181 unique country_names, 179 unique ISO3 codes...
# Out:
# C:\Users\anast\AppData\Local\Temp\ipykernel_27364\2291715595.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapped_iso3_pairs.rename(columns={'iso_3': 'iso3'}, inplace=True)
# 179

# %%
# displaying (country_name, iso3) duplicates
iso3_dups = mapped_iso3_pairs[mapped_iso3_pairs.duplicated()]
iso3_dups
# Out:
#            region_x iso3
# 16        Australia  AUS
# 58   Czech Republic  CZE
# 70           Russia  RUS
# 80          Germany  DEU
# 83          Germany  DEU
# 85           Greece  GRC
# 92            China  CHN
# 123         Lebanon  LBN
# 130        Malaysia  MYS
# 147        Malaysia  MYS
# 151          Canada  CAN
# 175          Russia  RUS
# 177         Germany  DEU
# 182       Singapore  SGP
# 201  Czech Republic  CZE
# 214           Syria  SYR
# 218          Russia  RUS
# 226         Vietnam  VNM
# 229           Yemen  YEM
# 230           Yemen  YEM
# 233        Zimbabwe  ZWE

# %%
# removing duplicated (country_name,iso3) pairs
mapped_iso3_pairs.drop_duplicates(inplace=True)
mapped_iso3_pairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 1 to 232
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   region_x  181 non-null    object
#  1   iso3      179 non-null    object
# dtypes: object(2)
# memory usage: 4.2+ KB
# C:\Users\anast\AppData\Local\Temp\ipykernel_27364\1010776367.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapped_iso3_pairs.drop_duplicates(inplace=True)

# %%
# adding 2nd part (calculated iso3 from 'region' part or from NOC as iso3)
mapped_iso3_calc = missed_iso3[~(missed_iso3['iso3'].isnull())][['region_x', 'iso3']]

# checking for dups: YES
# mapped_iso3_calc.shape, mapped_iso3_calc['region_x'].nunique(), mapped_iso3_calc['iso3'].nunique()
# RETURNED: ((20, 2), 19, 19)

# removing dups
mapped_iso3_calc.drop_duplicates(inplace=True)

# concatenating 1st and 2nd part (calculated) and 3rd part (6 googled codes)
iso3_pairs = pd.concat([mapped_iso3_pairs, mapped_iso3_calc, iso3_to_update], axis='index', ignore_index=True)

# checking for duplicates in contatenated list: NO, all good
# iso3_pairs.shape, iso3_pairs['region_x'].nunique(), iso3_pairs['iso3'].nunique()
# RETURNED: ((206, 2), 205, 202) # 2 entries for 'Serbia'

# fix 'Serbia' with correct iso3 = 'SRB'
iso3_pairs.loc[iso3_pairs['region_x'] == 'Serbia', 'iso3'] = 'SRB'

# remove dups from the final list
iso3_pairs.drop_duplicates(inplace=True)

# rename 'region_x' column
iso3_pairs.rename(columns={'region_x': 'country'}, inplace=True)
iso3_pairs # 205 rows
# Out:
#                               country iso3
# 0                             Lebanon  LBN
# 1                           Singapore  SGP
# 2                              Russia  RUS
# 3                         Afghanistan  AFG
# 4                             Albania  ALB
# ..                                ...  ...
# 200                 Republic of Congo  COG
# 201  Democratic Republic of the Congo  COD
# 202           Virgin Islands, British  VGB
# 204                       South Sudan  SSD
# 205                       Timor-Leste  TLS
#
# [205 rows x 2 columns]

# %%
# save countries with iso3 codes as csv-file
iso3_pairs.to_csv(path_or_buf='../olympics/iso3_pairs.csv', index=False,
                sep=',', na_rep='', header=True, mode='w', encoding='utf-8', decimal='.')
